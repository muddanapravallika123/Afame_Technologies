# %%
#Importing Necessary Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#Set display options to show all columns
pd.set_option('display.max_columns', None)

# %%
#Reading the dataset
Hr_df = pd.read_csv("HR Data.csv")

# %%
#Reading top 5 of the dataset
Hr_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#Reading last 5 of the dataset
Hr_df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
Hr_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
Hr_df.shape
# Out:
# (1470, 35)

# %%
Hr_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Checking Null values
Hr_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Removing unnecessary columns
columns_to_drop = ['EmployeeCount', 'Over18', 'StandardHours']
Hr_df.drop(columns=columns_to_drop, inplace=True)

# %%
print("Columns after dropping unnecessary ones:", Hr_df.columns)
# Out:
# Columns after dropping unnecessary ones: Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Rename Columns
Hr_df.rename(columns={
    'Age': 'age',
    'Attrition': 'attrition',
    'BusinessTravel': 'business_travel',
    'DailyRate': 'daily_rate',
    'DistanceFromHome': 'distance_from_home',
    'Education': 'education',
    'EducationField': 'education_field',
    'EmployeeNumber': 'employee_number',
    'EnvironmentSatisfaction': 'environment_satisfaction',
    'Gender': 'gender',
    'HourlyRate': 'hourly_rate',
    'JobInvolvement': 'job_involvement',
    'JobLevel': 'job_level',
    'JobRole': 'job_role',
    'JobSatisfaction': 'job_satisfaction',
    'MaritalStatus': 'marital_status',
    'MonthlyIncome': 'monthly_income',
    'MonthlyRate': 'monthly_rate',
    'NumCompaniesWorked': 'num_companies_worked',
    'OverTime': 'overtime',
    'PercentSalaryHike': 'percent_salary_hike',
    'PerformanceRating': 'performance_rating',
    'RelationshipSatisfaction': 'relationship_satisfaction',
    'StockOptionLevel': 'stock_option_level',
    'TotalWorkingYears': 'total_working_years',
    'TrainingTimesLastYear': 'training_times_last_year',
    'WorkLifeBalance': 'work_life_balance',
    'YearsAtCompany': 'years_at_company',
    'YearsInCurrentRole': 'years_in_current_role',
    'YearsSinceLastPromotion': 'years_since_last_promotion',
    'YearsWithCurrManager': 'years_with_curr_manager'
}, inplace=True)

# %%
print("Columns after renaming:", Hr_df.columns)
# Out:
# Columns after renaming: Index(['age', 'attrition', 'business_travel', 'daily_rate', 'Department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'overtime',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager'],
#       dtype='object')

# %%
#Eliminate Redundant Entries
Hr_df.drop_duplicates(inplace=True)
print("Shape after removing duplicates:", Hr_df.shape)
# Out:
# Shape after removing duplicates: (1470, 32)

# %%
# Sanitize Specific Columns
# Standardizing text case for categorical columns
Hr_df['gender'] = Hr_df['gender'].str.lower()
Hr_df['marital_status'] = Hr_df['marital_status'].str.lower()
Hr_df['education_field'] = Hr_df['education_field'].str.lower()
Hr_df['job_role'] = Hr_df['job_role'].str.lower()
Hr_df['business_travel'] = Hr_df['business_travel'].str.lower()
Hr_df['attrition'] = Hr_df['attrition'].str.lower()
Hr_df['overtime'] = Hr_df['overtime'].str.lower()

# %%
#Eliminate NaN Values
# Dropping rows with any NaN values
Hr_df.dropna(inplace=True)
print("Shape after handling NaN values:", Hr_df.shape)
# Out:
# Shape after handling NaN values: (1470, 32)

# %%
Hr_df['total_years_experience'] = Hr_df['total_working_years'] - Hr_df['years_at_company'] + Hr_df['years_in_current_role']

# %%
#Filtering out certain rows (e.g., removing employees with no working years)
Hr_df = Hr_df[Hr_df['total_working_years'] > 0]

# %%
Hr_df.to_csv('cleaned_hr_dataset.csv', index=False)

# %%
print(Hr_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1459 non-null   int64
#  1   attrition                   1459 non-null   object
#  2   business_travel             1459 non-null   object
#  3   daily_rate                  1459 non-null   int64
#  4   Department                  1459 non-null   object
#  5   distance_from_home          1459 non-null   int64
#  6   education                   1459 non-null   int64
#  7   education_field             1459 non-null   object
#  8   employee_number             1459 non-null   int64
#  9   environment_satisfaction    1459 non-null   int64
#  10  gender                      1459 non-null   object
#  11  hourly_rate                 1459 non-null   int64
#  12  job_involvement             1459 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Hr_df.hist(bins=20, figsize=(30, 15))
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(Hr_df.corr(), cmap='hot', linewidths=0.5, linecolor='black')
plt.title('Correlation Heatmap')
plt.show()

# %%
##checking the unique values count in Hr_df
Hr_df.nunique()
# Out:
# age                             42
# attrition                        2
# business_travel                  3
# daily_rate                     883
# Department                       3
# distance_from_home              29
# education                        5
# education_field                  6
# employee_number               1459
# environment_satisfaction         4
# gender                           2
# hourly_rate                     71
# job_involvement                  4
# job_level                        5
# job_role                         9
# job_satisfaction                 4
# marital_status                   3
# monthly_income                1338
# monthly_rate                  1416
# num_companies_worked            10
# overtime                         2
# percent_salary_hike             15
# performance_rating               2
# relationship_satisfaction        4
# stock_option_level               4
# total_working_years             39
# training_times_last_year         7
# ...

# %%
#Boxplot for Outlier Detection in Hr_df
# Draw boxplots for each feature
sns.set(style="ticks")
plt.figure(figsize=(45,30))
sns.boxplot(data=Hr_df)
sns.despine()
plt.title("Boxplot of Features")
plt.show()

# %%
#select categorical columns
categorical_columns = Hr_df.select_dtypes(include=['object']).columns

# %%
# Select numerical columns
numerical_columns = Hr_df.select_dtypes(exclude=['object']).columns

# %%
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# Index(['attrition', 'business_travel', 'Department', 'education_field',
#        'gender', 'job_role', 'marital_status', 'overtime'],
#       dtype='object')

# %%
print("\nNumerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# Index(['age', 'daily_rate', 'distance_from_home', 'education',
#        'employee_number', 'environment_satisfaction', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_satisfaction', 'monthly_income',
#        'monthly_rate', 'num_companies_worked', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager',
#        'total_years_experience'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
for column in categorical_columns:
    Hr_df[column] = label_encoder.fit_transform(Hr_df[column])

# %%
Hr_df.head()
# Out:
#    age  attrition  business_travel  daily_rate  Department  \
# 0   41          1                2        1102           2
# 1   49          0                1         279           1
# 2   37          1                2        1373           1
# 3   33          0                1        1392           1
# 4   27          0                2         591           1
#
#    distance_from_home  education  education_field  employee_number  \
# 0                   1          2                1                1
# 1                   8          1                1                2
# 2                   2          2                4                4
# 3                   3          4                1                5
# 4                   2          1                3                7
#
#    environment_satisfaction  gender  hourly_rate  job_involvement  job_level  \
# 0                         2       0           94                3          2
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
Hr_df[numerical_columns] = scaler.fit_transform(Hr_df[numerical_columns])

# %%
Hr_df.head()
# Out:
#         age  attrition  business_travel  daily_rate  Department  \
# 0  0.436477          1                2    0.740482           2
# 1  1.322178          0                1   -1.301137           1
# 2 -0.006374          1                2    1.412753           1
# 3 -0.449225          0                1    1.459887           1
# 4 -1.113501          0                2   -0.527157           1
#
#    distance_from_home  education  education_field  employee_number  \
# 0           -1.010448  -0.895253                1        -1.703106
# 1           -0.147957  -1.871467                1        -1.701445
# 2           -0.887235  -0.895253                4        -1.698122
# 3           -0.764022   1.057175                1        -1.696461
# 4           -0.887235  -1.871467                3        -1.693138
#
#    environment_satisfaction  gender  hourly_rate  job_involvement  job_level  \
# 0                 -0.657804       0     1.382934         0.380464  -0.065020
# ...
